# %%
import requests

test_data = {
    "Pregnancies": 1,
    "Glucose": 95,
    "BloodPressure": 70,
    "SkinThickness": 22,
    "Insulin": 85,
    "BMI": 24.5,
    "DiabetesPedigreeFunction": 0.2,
    "Age": 25,
    "min_similarity": 0.95
}

response = requests.post("http://localhost:8003/analyze", json=test_data)
print(response.json())
