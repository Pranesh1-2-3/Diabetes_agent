# %%
import requests

test_data = {
    "Pregnancies": 1,
    "Glucose": 95,
    "BloodPressure": 70,
    "SkinThickness": 22,
    "Insulin": 85,
    "BMI": 24.5,
    "DiabetesPedigreeFunction": 0.2,
    "Age": 25
}

response = requests.post("http://localhost:8003/analyze", json=test_data)
print(response.json())
# Out:
# {'message': "Diabetes Risk Assessment: Low Risk\n\nSummary: The patient is at low risk of diabetes based on the provided medical data and guidelines.\n\nRecommended Actions:\n1. Recommend a healthy diet and regular physical activity to the patient to prevent or delay the onset of type 2 diabetes.\n2. Schedule regular screening and treatment for complications, such as foot care, kidney disease, and eye exams, as recommended by the WHO and IDF guidelines.\n3. Monitor the patient's blood glucose levels and adjust treatment plans as necessary to prevent hyperglycemia and its complications.\n\nSources: WHO Fact Sheet: Diabetes, IDF Atlas: Global Diabetes Data & Statistics"}
